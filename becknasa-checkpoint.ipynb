# %% [markdown]
# # Valley Harpy Eagle

# %% [markdown]
# Bla bla bla bla bla bla bla bla bla bla bla

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline

# %%
df=pd.read_csv('Focos_2020-01-01_2020-10-03.csv', low_memory=False)

# %%
df.tail()
# Out:
#                     datahora satelite    pais              estado  \
# 3687009  2020/10/01 17:54:00  NPP-375  Brasil  MATO GROSSO DO SUL
# 3687010  2020/10/01 17:54:00  NPP-375  Brasil  MATO GROSSO DO SUL
# 3687011  2020/01/01 17:36:36  NOAA-20  Brasil   RIO GRANDE DO SUL
# 3687012  2020/01/01 17:36:36  NOAA-20  Brasil   RIO GRANDE DO SUL
# 3687013  2020/01/01 17:36:36  NOAA-20  Brasil      SANTA CATARINA
#
#                          municipio           bioma  diasemchuva  precipitacao  \
# 3687009                    CORUMBA        Pantanal         11.0           0.0
# 3687010                    CORUMBA        Pantanal         11.0           0.0
# 3687011                    CAPITAO  Mata Atlantica          0.0           0.0
# 3687012                    CAPITAO  Mata Atlantica          0.0           0.0
# 3687013  BALNEARIO ARROIO DO SILVA  Mata Atlantica         10.0           3.9
#
#          riscofogo  latitude  longitude   frp
# 3687009        1.0  -18.2139   -56.0659  11.1
# 3687010        1.0  -18.2086   -56.0696  10.0
# 3687011        0.0  -29.2563   -52.0030   NaN
# 3687012        0.0  -29.2558   -52.0001   NaN
# 3687013     -999.0  -28.9814   -49.4144   NaN

# %%
df.where(df["bioma"] == "Pantanal" ).tail()
# Out:
#                     datahora satelite    pais              estado municipio  \
# 3687009  2020/10/01 17:54:00  NPP-375  Brasil  MATO GROSSO DO SUL   CORUMBA
# 3687010  2020/10/01 17:54:00  NPP-375  Brasil  MATO GROSSO DO SUL   CORUMBA
# 3687011                  NaN      NaN     NaN                 NaN       NaN
# 3687012                  NaN      NaN     NaN                 NaN       NaN
# 3687013                  NaN      NaN     NaN                 NaN       NaN
#
#             bioma  diasemchuva  precipitacao  riscofogo  latitude  longitude  \
# 3687009  Pantanal         11.0           0.0        1.0  -18.2139   -56.0659
# 3687010  Pantanal         11.0           0.0        1.0  -18.2086   -56.0696
# 3687011       NaN          NaN           NaN        NaN       NaN        NaN
# 3687012       NaN          NaN           NaN        NaN       NaN        NaN
# 3687013       NaN          NaN           NaN        NaN       NaN        NaN
#
#           frp
# 3687009  11.1
# 3687010  10.0
# 3687011   NaN
# 3687012   NaN
# 3687013   NaN
